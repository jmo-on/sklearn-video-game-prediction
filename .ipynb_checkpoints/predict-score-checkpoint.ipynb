# %%
import pandas as pd

vgscore_data = pd.read_csv("vgscore.csv")

vgscore_data
# Out:
#                                                name      platform  \
# 0              The Legend of Zelda: Ocarina of Time    Nintendo64
# 1                          Tony Hawk's Pro Skater 2   PlayStation
# 2                               Grand Theft Auto IV  PlayStation3
# 3                                       SoulCalibur     Dreamcast
# 4                               Grand Theft Auto IV       Xbox360
# ...                                             ...           ...
# 17939                        Vroom in the Night Sky        Switch
# 17940           Leisure Suit Larry: Box Office Bust  PlayStation3
# 17941                                         Yaris       Xbox360
# 17942                     Ride to Hell: Retribution            PC
# 17943  Family Party: 30 Great Games Obstacle Arcade          WiiU
#
#                    r-date  score user score               developer  \
# 0       November 23, 1998     99        9.1                Nintendo
# 1      September 20, 2000     98        7.4  NeversoftEntertainment
# 2          April 29, 2008     98        7.6           RockstarNorth
# 3       September 8, 1999     98        8.5                   Namco
# 4          April 29, 2008     98        7.9           RockstarNorth
# ...                   ...    ...        ...                     ...
# 17939       April 5, 2017     17        3.1                 Poisoft
# 17940         May 5, 2009     17        1.9                  Team17
# 17941    October 10, 2007     17        4.3   BackboneEntertainment
# 17942       June 24, 2013     16        1.3    Eutechnyx,DeepSilver
# 17943    December 4, 2012     11        2.0             ArtCo.,Ltd.
#
#                                                    genre  \
# 0                               Action Adventure,Fantasy
# 1                       Sports,Alternative,Skateboarding
# 2              Action Adventure,Modern,Modern,Open-World
# 3                                     Action,Fighting,3D
# 4              Action Adventure,Modern,Modern,Open-World
# ...                                                  ...
# 17939                           Sports,Individual,Biking
# 17940  Action Adventure,Adventure,Third-Person,Open-W...
# 17941            Driving,Racing,Arcade,Arcade,Automobile
# 17942  Driving,Modern,Racing,Motorcycle,Motocross,Mod...
# 17943         Miscellaneous,Party,Party,Party / Minigame
#
#                      players  critics  users
# 0                   1 Player       22   5749
# 1                       1-2        19    647
# 2                   1 Player       64   3806
# 3                       1-2        24    324
# 4                   1 Player       86   3364
# ...                      ...      ...    ...
# 17939  No Online Multiplayer       15    105
# 17940  No Online Multiplayer       11     45
# 17941              2  Online        7    129
# 17942                No info        9    581
# 17943  No Online Multiplayer        8    151
#
# [17944 rows x 10 columns]

# %%
vgscore_data.isnull().any()
# Out:
# name          False
# platform      False
# r-date        False
# score         False
# user score    False
# developer     False
# genre         False
# players        True
# critics       False
# users         False
# dtype: bool

# %%
vgscore_data = vgscore_data.drop(columns=["players"])
vgscore_data
# Out:
#                                                name      platform  \
# 0              The Legend of Zelda: Ocarina of Time    Nintendo64
# 1                          Tony Hawk's Pro Skater 2   PlayStation
# 2                               Grand Theft Auto IV  PlayStation3
# 3                                       SoulCalibur     Dreamcast
# 4                               Grand Theft Auto IV       Xbox360
# ...                                             ...           ...
# 17939                        Vroom in the Night Sky        Switch
# 17940           Leisure Suit Larry: Box Office Bust  PlayStation3
# 17941                                         Yaris       Xbox360
# 17942                     Ride to Hell: Retribution            PC
# 17943  Family Party: 30 Great Games Obstacle Arcade          WiiU
#
#                    r-date  score user score               developer  \
# 0       November 23, 1998     99        9.1                Nintendo
# 1      September 20, 2000     98        7.4  NeversoftEntertainment
# 2          April 29, 2008     98        7.6           RockstarNorth
# 3       September 8, 1999     98        8.5                   Namco
# 4          April 29, 2008     98        7.9           RockstarNorth
# ...                   ...    ...        ...                     ...
# 17939       April 5, 2017     17        3.1                 Poisoft
# 17940         May 5, 2009     17        1.9                  Team17
# 17941    October 10, 2007     17        4.3   BackboneEntertainment
# 17942       June 24, 2013     16        1.3    Eutechnyx,DeepSilver
# 17943    December 4, 2012     11        2.0             ArtCo.,Ltd.
#
#                                                    genre  critics  users
# 0                               Action Adventure,Fantasy       22   5749
# 1                       Sports,Alternative,Skateboarding       19    647
# 2              Action Adventure,Modern,Modern,Open-World       64   3806
# 3                                     Action,Fighting,3D       24    324
# 4              Action Adventure,Modern,Modern,Open-World       86   3364
# ...                                                  ...      ...    ...
# 17939                           Sports,Individual,Biking       15    105
# 17940  Action Adventure,Adventure,Third-Person,Open-W...       11     45
# 17941            Driving,Racing,Arcade,Arcade,Automobile        7    129
# 17942  Driving,Modern,Racing,Motorcycle,Motocross,Mod...        9    581
# 17943         Miscellaneous,Party,Party,Party / Minigame        8    151
#
# [17944 rows x 9 columns]

# %%
def is_not_ascii(value):
    if isinstance(value, str):
        return any(ord(s) >= 128 for s in value)
    return False

for col in vgscore_data.columns.tolist():
    non_ascii_rows = vgscore_data[vgscore_data[col].apply(is_not_ascii)]
    if not non_ascii_rows.empty:
        print(f"Column: {col}")
        print(non_ascii_rows)
# Out:
# Column: name
# Column: platform
# Column: r-date
# Column: score
# Column: user score
# Column: developer
# Column: genre
# Column: critics
# Column: users
